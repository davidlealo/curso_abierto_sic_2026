# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/curso_abierto_sic_2026/blob/main/004_clase_abierta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pseudocodigo

# %%
# Nomenclatura slide 70

# Variable

variable = "Palabra"

# %%
import sys

# %%
import sys

# Variable is defined here to ensure it's available for memory size calculation
variable = "Palabra"

memory_address = id(variable)
print(f"The memory address of 'variable' is: {memory_address}")
# Out:
# The memory address of 'variable' is: 133765450496208

# %%
variable = "Hola mundo!"

# %%
memory_address = id(variable)
print(f"The memory address of 'variable' is: {memory_address}")
# Out:
# The memory address of 'variable' is: 133765430914544

# %%
entero = 1

# %%
memory_address = id(entero)
print(f"The memory address of 'entero' is: {memory_address}")
# Out:
# The memory address of 'entero' is: 11645352

# %%
entero = 2

# %%
memory_address = id(entero)
print(f"The memory address of 'entero' is: {memory_address}")
# Out:
# The memory address of 'entero' is: 11645384

# %%
palabra1 = "Hola"
palabra2 = "Hola"

print(palabra1 == palabra2)
# Out:
# True

# %%
print(id(palabra1))
print(id(palabra2))
# Out:
# 133765429444656
# 133765429444656

# %%
nombre = "Luis"

# %%
nombre
# Out:
# 'Luis'

# %%
Nombre = "Sebastian"

# %%
nombre
# Out:
# 'Luis'

# %% [markdown]
# ### Naming Conventions Examples
#
# There are several common naming conventions used in programming to improve code readability and maintainability. Here are some examples:

# %% [markdown]
# #### 1. camelCase (Lower Camel Case)
#
# *   **Description**: The first letter of the first word is lowercase, and the first letter of each subsequent concatenated word is capitalized.
# *   **Common Use**: Variables, functions, and methods in languages like JavaScript, Java, and sometimes Python (though `snake_case` is preferred for variables in Python).

# %%
# Example of camelCase
myVariableName = "This is a camel case variable"
calculateTotalPrice = lambda price, quantity: price * quantity

print(myVariableName)
print(calculateTotalPrice(10, 5))
# Out:
# This is a camel case variable
# 50

# %% [markdown]
# #### 2. snake_case
#
# *   **Description**: All letters are lowercase, and words are separated by underscores (`_`).
# *   **Common Use**: Variables, functions, and module names in Python (PEP 8 standard), and database column names.

# %%
# Example of snake_case
my_variable_name = "This is a snake case variable"
calculate_total_price = lambda price, quantity: price * quantity

print(my_variable_name)
print(calculate_total_price(10, 5))
# Out:
# This is a snake case variable
# 50

# %% [markdown]
# #### 3. PascalCase (Upper Camel Case)
#
# *   **Description**: The first letter of each concatenated word is capitalized.
# *   **Common Use**: Class names in many object-oriented languages (including Python, as per PEP 8), and sometimes types or constructors.

# %%
# Example of PascalCase
class MyClassName:
    def __init__(self, value):
        self.value = value

def my_function_name():
    pass # Function names should typically be snake_case

my_object = MyClassName(100)
print(f"Created an object of class MyClassName with value: {my_object.value}")
# Out:
# Created an object of class MyClassName with value: 100

# %% [markdown]
# #### 4. kebab-case
#
# *   **Description**: All letters are lowercase, and words are separated by hyphens (`-`).
# *   **Common Use**: File names, URL slugs, and sometimes CSS class names. It is generally **not used** for variable or function names in most programming languages because the hyphen is interpreted as a subtraction operator.

# %% [markdown]
# #### 5. SCREAMING_SNAKE_CASE
#
# *   **Description**: All letters are uppercase, and words are separated by underscores (`_`).
# *   **Common Use**: Constants and immutable values.

# %%
# Example of SCREAMING_SNAKE_CASE
MAX_VALUE = 1000
DEFAULT_TIMEOUT_SECONDS = 30

print(f"Maximum allowed value: {MAX_VALUE}")
print(f"Default timeout: {DEFAULT_TIMEOUT_SECONDS} seconds")
# Out:
# Maximum allowed value: 1000
# Default timeout: 30 seconds

# %%
# Puedo crear una variable que sea un caracter pero no
# puedi usar un número como variable

a = 1
b = 2

print(a + b)
# Out:
# 3

# %%
a = 1

# %%
a = 2

# %%
a
# Out:
# 2

# %%
numero_1 = 2

# %%
n1mero = 3

# %%
_numero = 2

# %% [markdown]
# ### Rules for Writing Variable Names in Python
#
# In Python, there are specific rules and conventions for naming variables to ensure your code is readable and doesn't lead to syntax errors. Here are the main rules:

# %% [markdown]
# #### 1. Cannot start with a number
#
# Variable names cannot begin with a numeric digit. They must start with a letter (a-z, A-Z) or an underscore (`_`).

# %%
# Valid:
_my_variable = 10
variable_1 = 20

# Invalid (will raise a SyntaxError if uncommented):
# 1variable = 30
# 2nd_name = 'Python'

print(f"_my_variable: {_my_variable}")
print(f"variable_1: {variable_1}")
# Out:
# _my_variable: 10
# variable_1: 20

# %% [markdown]
# #### 2. Can only contain alphanumeric characters and underscores
#
# Variable names can only contain letters (a-z, A-Z), numbers (0-9), and underscores (`_`). Special characters like `!`, `@`, `#`, `$`, `%`, etc., are not allowed.

# %%
# Valid:
first_name = "Alice"
user_id_007 = 7

# Invalid (will raise a SyntaxError if uncommented):
# user-name = "Bob" # Hyphen is not allowed
# total$ = 100 # Dollar sign is not allowed

print(f"first_name: {first_name}")
print(f"user_id_007: {user_id_007}")
# Out:
# first_name: Alice
# user_id_007: 7

# %% [markdown]
# #### 3. Case-sensitive
#
# Python variable names are case-sensitive. `myVariable` is different from `myvariable`.

# %%
# Example of case-sensitivity
myVar = 5
myvar = 10

print(f"myVar: {myVar}")
print(f"myvar: {myvar}")
# Out:
# myVar: 5
# myvar: 10

# %% [markdown]
# #### 4. Cannot be Python keywords (reserved words)
#
# You cannot use any of Python's reserved keywords as variable names. Keywords are words that have special meaning in Python, like `if`, `else`, `while`, `for`, `class`, `def`, `import`, `True`, `False`, `None`, etc.

# %%
import keyword

# Print all Python keywords
print("Python Keywords:", keyword.kwlist)

# Valid:
my_if_statement = "valid"

# Invalid (will raise a SyntaxError if uncommented):
# class = "MyClass"
# import = "module"

print(f"my_if_statement: {my_if_statement}")
# Out:
# Python Keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# my_if_statement: valid

# %% [markdown]
# #### 5. Short and descriptive
#
# While not a strict rule, it's a strong convention (PEP 8) to use short, descriptive names that indicate the purpose of the variable. Avoid overly generic names like `x` or `data` unless their context is extremely clear. Python prefers `snake_case` for variable and function names.

# %% [markdown]
# ### Cuadro de Precedencia de Operadores
#
# El **cuadro de precedencia de operadores** (o jerarquía de operadores) es un conjunto de reglas que define el orden en el que se evalúan las operaciones en una expresión matemática o lógica. Al igual que en las matemáticas, donde la multiplicación y división se realizan antes que la suma y la resta, los lenguajes de programación siguen reglas similares para evitar ambigüedades y asegurar que las expresiones se evalúen de manera consistente.
#
# #### ¿Por qué es importante?
#
# La precedencia de operadores es crucial porque determina el resultado de una expresión. Si no se respetan estas reglas, o si no se utilizan paréntesis para forzar un orden específico, el resultado podría ser diferente al esperado.
#
# #### Reglas Generales (de mayor a menor precedencia):
#
# Aunque el orden exacto puede variar ligeramente entre lenguajes y para operadores muy específicos, las reglas generales suelen ser las siguientes:
#
# 1.  **Paréntesis `()`**: Las operaciones dentro de paréntesis siempre se evalúan primero. Permiten anular la precedencia por defecto.
# 2.  **Operadores Unarios**: Operadores que actúan sobre un solo operando, como el signo negativo (`-`), el operador de negación lógica (`not`), etc.
# 3.  **Potencia `**`** (exponenciación).
# 4.  **Multiplicación `*`, División `/`, División entera `//`, Módulo `%`**.
# 5.  **Suma `+`, Resta `-`**.
# 6.  **Operadores de Desplazamiento (Bitwise Shift)**: `<<`, `>>`.
# 7.  **Operadores Relacionales / de Comparación**: `==`, `!=`, `>`, `<`, `>=`, `<=`, `is`, `is not`, `in`, `not in`.
# 8.  **Operadores Lógicos (Bitwise AND, OR, XOR)**: `&`, `^`, `|`.
# 9.  **Operadores Lógicos Booleanos**: `not` (ya mencionado como unario), `and`, `or`.
# 10. **Operadores de Asignación**: `=`, `+=`, `-=`, `*=`, `/=`, etc.
#
# #### Ejemplo en Python:
#
# Veamos un ejemplo simple para ilustrar cómo funciona la precedencia en Python:

# %%
# Operadores slide 149

# %%
resultado1 = 10 + 5 * 2 # Sin paréntesis
print(f"Resultado 1 (10 + 5 * 2): {resultado1}") # Se evalúa 5 * 2 primero, luego la suma

resultado2 = (10 + 5) * 2 # Con paréntesis
print(f"Resultado 2 ((10 + 5) * 2): {resultado2}") # Se evalúa (10 + 5) primero, luego la multiplicación

resultado3 = 2 ** 3 + 4 * 2
print(f"Resultado 3 (2 ** 3 + 4 * 2): {resultado3}") # 2**3 (8), luego 4*2 (8), luego 8+8

resultado4 = not True and False or True
print(f"Resultado 4 (not True and False or True): {resultado4}") # not True (False), luego False and False (False), luego False or True (True)
# Out:
# Resultado 1 (10 + 5 * 2): 20
# Resultado 2 ((10 + 5) * 2): 30
# Resultado 3 (2 ** 3 + 4 * 2): 16
# Resultado 4 (not True and False or True): True

# %%
20/3
# Out:
# 6.666666666666667

# %%
20 % 3
# Out:
# 2

# %%
20 % 2
# Out:
# 0

# %%
20/2
# Out:
# 10.0

# %%
def es_par(numero):
    if numero % 2 == 0:
        return print("Es par")
    else:
        return print("No es par")

# %%
es_par(3)
# Out:
# No es par

# %%
es_par(87869886556776798)
# Out:
# Es par

# %% [markdown]
# ### El Operador de Módulo (`%`)
#
# El operador de módulo, representado por el símbolo `%`, es un operador aritmético que devuelve el **resto** de una división. En otras palabras, si divides un número `a` entre un número `b` (es decir, `a / b`), el resultado del operador de módulo `a % b` es lo que queda después de realizar la división entera.
#
# **Sintaxis básica:**
#
# ```python
# resultado = dividendo % divisor
# ```
#
# Por ejemplo:
# *   `10 % 3` es `1` (porque 10 dividido por 3 es 3 con un resto de 1).
# *   `10 % 2` es `0` (porque 10 dividido por 2 es 5 con un resto de 0).
# *   `7 % 5` es `2` (porque 7 dividido por 5 es 1 con un resto de 2).
#
# #### Casos de Uso Prácticos:
#
# El operador de módulo es increíblemente versátil y se utiliza en muchas situaciones, incluyendo:
#
# 1.  **Comprobar si un número es par o impar**: Si un número dividido por 2 tiene un resto de 0, es par. Si el resto es 1, es impar.
# 2.  **Determinar si un número es divisible por otro**: Si `a % b` es 0, significa que `a` es divisible por `b`.
# 3.  **Operaciones cíclicas o rotaciones**: Útil para mantener un valor dentro de un rango específico, como los días de la semana, las horas en un reloj o índices en una lista que se repiten.
# 4.  **Extraer el último dígito de un número**: El módulo 10 (`% 10`) de un número entero siempre dará su último dígito.
# 5.  **Conversión de unidades de tiempo**: Por ejemplo, calcular los minutos restantes después de convertir segundos a horas.

# %%
# 1. Comprobar si un número es par o impar
numero1 = 10
numero2 = 7

print(f"¿{numero1} es par? {numero1 % 2 == 0}")
print(f"¿{numero2} es par? {numero2 % 2 == 0}")

# 2. Determinar si un número es divisible por otro
num = 15
divisor = 3
print(f"¿{num} es divisible por {divisor}? {num % divisor == 0}")

num = 17
divisor = 3
print(f"¿{num} es divisible por {divisor}? {num % divisor == 0}")

# 3. Operaciones cíclicas (ej. días de la semana)
dias_semana = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
dia_actual = 0 # Lunes

# ¿Qué día será en 3 días?
proximo_dia_indice = (dia_actual + 3) % 7
print(f"Si hoy es {dias_semana[dia_actual]}, en 3 días será {dias_semana[proximo_dia_indice]}")

# ¿Qué día será en 10 días?
proximo_dia_indice_futuro = (dia_actual + 10) % 7
print(f"Si hoy es {dias_semana[dia_actual]}, en 10 días será {dias_semana[proximo_dia_indice_futuro]}")

# 4. Extraer el último dígito de un número
numero_largo = 1234567
ultimo_digito = numero_largo % 10
print(f"El último dígito de {numero_largo} es: {ultimo_digito}")

# 5. Conversión de unidades de tiempo (ej. segundos a minutos y segundos)
total_segundos = 150
minutos = total_segundos // 60 # División entera para obtener los minutos
segundos_restantes = total_segundos % 60 # Módulo para obtener los segundos restantes
print(f"{total_segundos} segundos son {minutos} minutos y {segundos_restantes} segundos.")
# Out:
# ¿10 es par? True
# ¿7 es par? False
# ¿15 es divisible por 3? True
# ¿17 es divisible por 3? False
# Si hoy es Lunes, en 3 días será Jueves
# Si hoy es Lunes, en 10 días será Jueves
# El último dígito de 1234567 es: 7
# 150 segundos son 2 minutos y 30 segundos.

# %%
# 5. Conversión de unidades de tiempo (ej. segundos a minutos y segundos)
total_segundos = 150
total_segundos
# Out:
# 150

# %%
minutos = total_segundos // 60 # División entera para obtener los minutos
minutos
# Out:
# 2

# %%
segundos_restantes = total_segundos % 60 # Módulo para obtener los segundos restantes
segundos_restantes
# Out:
# 30

# %%
print(f"{total_segundos} segundos son {minutos} minutos y {segundos_restantes} segundos.")
# Out:
# 150 segundos son 2 minutos y 30 segundos.

# %%
cantidad_segundos= 988757646499875643322333322433445569998878

# %% [markdown]
# **988,757,646,499,875,643,322,333,322,433,445,569,998,878**
#
# En palabras:
#
# > **Novecientos ochenta y ocho sextillones setecientos cincuenta y siete mil seiscientos cuarenta y seis quintillones cuatrocientos noventa y nueve mil ochocientos setenta y cinco cuatrillones seiscientos cuarenta y tres mil trescientos veintidós trillones trescientos treinta y tres mil trescientos veintidós billones cuatrocientos treinta y tres mil cuatrocientos cuarenta y cinco millones quinientos sesenta y nueve mil novecientos setenta y ocho**
#
# Tiene **42 dígitos**, por lo que cae en la escala de los **sextillones** (usando la escala larga hispanohablante) o *tredecillones* en escala corta anglosajona.

# %% [markdown]
# Para contexto: la edad del universo es de unos 13,800,000,000 años (13.8 mil millones). Este número de segundos equivale a aproximadamente 2,270,000,000,000,000,000,000,000 veces la edad del universo. 🤯

# %% [markdown]
# ¡Exacto! El número es tan gigantesco que necesitas unidades mucho mayores. Aquí la escala completa:
#
# | Unidad | Equivale a |
# |--------|-----------|
# | Década | 10 años |
# | Siglo | 100 años |
# | Milenio | 1,000 años |
# | Megaanio | 1,000,000 años |
# | Gigaanio | 1,000,000,000 años |
# | Teraanio | 1,000,000,000,000 años |
# | Petaanio | 1,000,000,000,000,000 años |
# | Exaanio | 1,000,000,000,000,000,000 años |
# | Zettaanio | 1,000,000,000,000,000,000,000 años |
# | Yottaanio | 1,000,000,000,000,000,000,000,000 años |
#
# ¿Quiero que ejecute el programa extendido con todas estas unidades para ver en cuál "encaja" el número y obtener el desglose final completo?

# %%
cantidad_segundos= 988757646499875643322333322433445569998878

# %%
minutos = cantidad_segundos // 60
horas = minutos // 60
dias = horas // 24
anos = dias // 365
siglos = anos // 100

# %% [markdown]
# ¡Aquí está el desglose final completo! 🎉
#
# **=== DESGLOSE COMPLETO ===**
#
# | Unidad | Cantidad |
# |--------|----------|
# | Yottaanios (×10²⁴ años) | **31,331,839,129** |
# | Zettaanios (×10²¹ años) | 80 |
# | Exaanios (×10¹⁸ años) | 653 |
# | Petaanios (×10¹⁵ años) | 893 |
# | Teraanios (×10¹² años) | 906 |
# | Gigaanios (×10⁹ años) | 169 |
# | Megaanios (×10⁶ años) | 114 |
# | Milenios | 46 |
# | Siglos | 8 |
# | Décadas | 7 |
# | Años | 2 |
# | Semanas | 3 |
# | Días | 4 |
# | Horas | 3 |
# | Minutos | 14 |
# | Segundos | **38** |
#
# Entonces la respuesta final completa es:
#
# > **31,331,839,129 Yottaanios**, 80 Zettaanios, 653 Exaanios, 893 Petaanios, 906 Teraanios, 169 Gigaanios, 114 Megaanios, 46 milenios, 8 siglos, 7 décadas, 2 años, 3 semanas, 4 días, 3 horas, 14 minutos y 38 segundos. ⏳
#
# El número es tan grande que ni con **Yottaanios** (la unidad más grande que existe con nombre estándar) se puede expresar en una sola cifra pequeña — ¡se necesitan más de 31 mil millones de ellos!

# %% [markdown]
# ### Operadores de Comparación (Relacionales)
#
# Los **operadores de comparación** se utilizan para comparar dos valores y determinar la relación entre ellos. El resultado de una operación de comparación siempre es un valor booleano: `True` (verdadero) o `False` (falso).
#
# Estos operadores son esenciales para el control de flujo en los programas, ya que permiten tomar decisiones basadas en condiciones (por ejemplo, en sentencias `if`, `elif`, `while`).
#
# #### Tipos de Operadores de Comparación en Python:
#
# Aquí tienes los operadores de comparación más comunes en Python:
#
# 1.  **Igual a (`==`)**:
#     *   Comprueba si dos valores son iguales.
#     *   Ejemplo: `5 == 5` devuelve `True`.
#     *   Ejemplo: `5 == 10` devuelve `False`.
#
# 2.  **Distinto de (`!=`)**:
#     *   Comprueba si dos valores no son iguales.
#     *   Ejemplo: `5 != 10` devuelve `True`.
#     *   Ejemplo: `5 != 5` devuelve `False`.
#
# 3.  **Mayor que (`>`)**:
#     *   Comprueba si el valor de la izquierda es mayor que el de la derecha.
#     *   Ejemplo: `10 > 5` devuelve `True`.
#     *   Ejemplo: `5 > 10` devuelve `False`.
#
# 4.  **Menor que (`<`)**:
#     *   Comprueba si el valor de la izquierda es menor que el de la derecha.
#     *   Ejemplo: `5 < 10` devuelve `True`.
#     *   Ejemplo: `10 < 5` devuelve `False`.
#
# 5.  **Mayor o igual que (`>=`)**:
#     *   Comprueba si el valor de la izquierda es mayor o igual que el de la derecha.
#     *   Ejemplo: `10 >= 10` devuelve `True`.
#     *   Ejemplo: `10 >= 5` devuelve `True`.
#
# 6.  **Menor o igual que (`<=`)**:
#     *   Comprueba si el valor de la izquierda es menor o igual que el de la derecha.
#     *   Ejemplo: `5 <= 5` devuelve `True`.
#     *   Ejemplo: `5 <= 10` devuelve `True`.
#
# #### Ejemplos Prácticos en Python:

# %%
# Ejemplo de 'Igual a' (==)
a = 10
b = 10
print(f"¿{a} == {b}? {a == b}")

c = 5
d = 8
print(f"¿{c} == {d}? {c == d}")

# Comparando cadenas de texto
nombre1 = "Alice"
nombre2 = "Alice"
print(f"¿'{nombre1}' == '{nombre2}'? {nombre1 == nombre2}")

nombre3 = "Bob"
nombre4 = "bob"
print(f"¿'{nombre3}' == '{nombre4}'? {nombre3 == nombre4}") # Fíjate que es sensible a mayúsculas/minúsculas
# Out:
# ¿10 == 10? True
# ¿5 == 8? False
# ¿'Alice' == 'Alice'? True
# ¿'Bob' == 'bob'? False

# %%
# Ejemplo de 'Distinto de' (!=)
x = 15
y = 20
print(f"¿{x} != {y}? {x != y}")

p = 30
q = 30
print(f"¿{p} != {q}? {p != q}")

# Comparando tipos diferentes (Python no suele lanzar error, pero el resultado puede ser False)
numero = 7
cadena = "7"
print(f"¿{numero} != '{cadena}'? {numero != cadena}")
# Out:
# ¿15 != 20? True
# ¿30 != 30? False
# ¿7 != '7'? True

# %%
# Ejemplo de 'Mayor que' (>)
edad_juan = 25
edad_maria = 20
print(f"¿La edad de Juan ({edad_juan}) es mayor que la de María ({edad_maria})? {edad_juan > edad_maria}")

valor1 = 100
valor2 = 150
print(f"¿{valor1} > {valor2}? {valor1 > valor2}")
# Out:
# ¿La edad de Juan (25) es mayor que la de María (20)? True
# ¿100 > 150? False

# %%
# Ejemplo de 'Menor que' (<)
temperatura_actual = 18
temperatura_maxima = 25
print(f"¿La temperatura actual ({temperatura_actual}) es menor que la máxima ({temperatura_maxima})? {temperatura_actual < temperatura_maxima}")

precio_a = 50
precio_b = 45
print(f"¿{precio_a} < {precio_b}? {precio_a < precio_b}")
# Out:
# ¿La temperatura actual (18) es menor que la máxima (25)? True
# ¿50 < 45? False

# %%
# Ejemplo de 'Mayor o igual que' (>=)
puntuacion_minima = 70
puntuacion_alumno = 75
print(f"¿La puntuación del alumno ({puntuacion_alumno}) es mayor o igual que la mínima ({puntuacion_minima})? {puntuacion_alumno >= puntuacion_minima}")

valor_stock = 100
limite_venta = 100
print(f"¿{valor_stock} >= {limite_venta}? {valor_stock >= limite_venta}")
# Out:
# ¿La puntuación del alumno (75) es mayor o igual que la mínima (70)? True
# ¿100 >= 100? True

# %%
# Ejemplo de 'Menor o igual que' (<=)
estatura_requerida = 160
estatura_persona = 155
print(f"¿La estatura de la persona ({estatura_persona}) es menor o igual que la requerida ({estatura_requerida})? {estatura_persona <= estatura_requerida}")

stock_disponible = 50
cantidad_pedida = 50
print(f"¿{stock_disponible} <= {cantidad_pedida}? {stock_disponible <= cantidad_pedida}")
# Out:
# ¿La estatura de la persona (155) es menor o igual que la requerida (160)? True
# ¿50 <= 50? True
