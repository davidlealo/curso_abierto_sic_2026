# %% [markdown]
# # Quinta Sesión Cerrada — Emprender en Tecnología
#
# **Samsung Innovation Campus 2026 · Curso Abierto**
# Ejecutado por [ONG Innovacien](https://innovacien.org)
#
# ---
#
# > *"La iniciativa busca democratizar el acceso al código a través de un Curso Abierto intensivo de 50 horas, modalidad 100% flexible y sin requisitos previos de ingreso."*
#
# ## 🎯 Descripción de la sesión
#
# Sesión especial en formato **webinar** con dos invitados:
#
# - **Patricia Ibáñez** — Startup Chile (CORFO)
# - **Sebastián Doménech** — Fundador de [Agrolytics](https://agrolyticsapp.com/), empresa de tecnología agrícola
#
# La conversación explora cómo el dominio de **Python, datos e inteligencia artificial** puede ser el punto de partida para emprender en tecnología en Chile, qué caminos existen para financiar una startup desde etapas tempranas, y cómo programas como **Startup Chile** apoyan a emprendedores tecnológicos con capital, mentoría y red internacional.

# %% [markdown]
# ## 🎥 Video de la sesión
#
# [![Ver en YouTube](https://img.youtube.com/vi/Rctcf4k1xjQ/maxresdefault.jpg)](https://youtu.be/Rctcf4k1xjQ)
#
# 👉 [https://youtu.be/Rctcf4k1xjQ](https://youtu.be/Rctcf4k1xjQ)

# %%
# Embed del video directamente en el notebook
from IPython.display import YouTubeVideo
YouTubeVideo('Rctcf4k1xjQ', width=800, height=450)

# %% [markdown]
# ## 👥 Invitados
#
# ### Sebastián Doménech
# - 🌱 **Empresa:** [Agrolytics](https://agrolyticsapp.com/) — soluciones tecnológicas para el agro
# - 💼 **LinkedIn:** [linkedin.com/in/sebastian-domenech](https://www.linkedin.com/in/sebastian-domenech/)
#
# ### Patricia Ibáñez
# - 🚀 **Organización:** [Startup Chile](https://startupchile.org/) — programa de CORFO que apoya startups tecnológicas en etapa temprana con capital, mentoría y red internacional

# %% [markdown]
# ## 🧠 Temas abordados
#
# ### 1. De aprender a emprender
# - Cómo las habilidades técnicas vistas en SIC 2026 (Python, datos, IA) son la base para construir productos tecnológicos reales
# - El caso concreto de Agrolytics: un producto construido desde Chile con tecnología accesible y alcance regional
#
# ### 2. Qué es Startup Chile
# - Programa de CORFO que financia, conecta y acelera startups tecnológicas en etapa temprana
# - Foco en soluciones escalables con impacto social o económico
# - Red internacional y acceso a ecosistemas globales
#
# ### 3. Cómo postular al programa BIG
# - Requisitos, etapas y criterios de selección
# - Tipos de financiamiento disponibles
# - Convocatoria BIG 11 (bases vigentes) y BIG 12 (próxima)
#
# ### 4. Consejos para emprendedores tech
# - Validar antes de construir
# - La importancia de combinar habilidades técnicas con visión de negocio
# - Recursos y comunidades disponibles en Chile

# %% [markdown]
# ## 📚 Recursos mencionados en la sesión
#
# | Recurso | Descripción | Enlace |
# |---|---|---|
# | Agrolytics | Empresa de Sebastián Doménech | [agrolyticsapp.com](https://agrolyticsapp.com/) |
# | LinkedIn Sebastián | Perfil profesional | [linkedin.com/in/sebastian-domenech](https://www.linkedin.com/in/sebastian-domenech/) |
# | Startup Chile | Sitio oficial del programa | [startupchile.org](https://startupchile.org/) |
# | Bases BIG 11 | Convocatoria actual (resolución CORFO) | [Ver PDF](https://startupchile.org/content/uploads/resolucioxxn-electroxxnica-exenta-nxx1457-de-2025-de-corfo-modifica-bases-start-up-chile-big-11.pdf) |
# | Brochure BIG 12 | Próxima convocatoria | [Ver PDF](https://startupchile.org/content/uploads/brochure-big-12-esp-1.pdf) |

# %%
# Links de recursos para acceso rápido
recursos = {
    "Agrolytics (empresa de Sebastián)": "https://agrolyticsapp.com/",
    "LinkedIn Sebastián Doménech": "https://www.linkedin.com/in/sebastian-domenech/",
    "Startup Chile": "https://startupchile.org/",
    "Bases BIG 11": "https://startupchile.org/content/uploads/resolucioxxn-electroxxnica-exenta-nxx1457-de-2025-de-corfo-modifica-bases-start-up-chile-big-11.pdf",
    "Brochure BIG 12": "https://startupchile.org/content/uploads/brochure-big-12-esp-1.pdf"
}

print("📎 Recursos de la Sesión 5 — Emprender en Tecnología")
print("=" * 55)
for nombre, url in recursos.items():
    print(f"\n🔗 {nombre}")
    print(f"   {url}")

# %% [markdown]
# ## 💡 Reflexión final
#
# Esta sesión conecta los contenidos técnicos del curso con el mundo real del emprendimiento tecnológico en Chile. Aprender Python, entender datos e introducirse a la IA no solo abre puertas laborales — también puede ser el punto de partida para construir tu propia solución tecnológica.
#
# **Programas como Startup Chile existen para apoyar exactamente ese salto.**
#
# ---
#
# *Curso Abierto SIC 2026 · ONG Innovacien · Samsung Innovation Campus*
