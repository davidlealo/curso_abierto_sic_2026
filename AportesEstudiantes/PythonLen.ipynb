# %% [markdown]
# <a href="https://colab.research.google.com/github/fernand-css/curso_abierto_sic_2026/blob/main/AportesEstudiantes/PythonLen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Función len()**

# %% [markdown]
# Está función mide la longitud de los elementos de una lista

# %%
lista = [1,2,3,4,5,6,7,8,9]

# %%
len(lista)
# Out:
# 9
